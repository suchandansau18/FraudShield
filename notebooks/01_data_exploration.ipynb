# %%
import pandas as pd
import numpy as np

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Environment is working!")
# Out:
# Pandas: 3.0.5
# NumPy: 2.5.2
# Environment is working!

# %%
file_path = "../data/raw/PS_20174392719_1491204439457_log.csv"

df_sample = pd.read_csv(
    file_path,
    nrows=10000
)

print("Rows and columns:", df_sample.shape)
# Out:
# Rows and columns: (10000, 11)

# %%
df_sample.columns.tolist()
# Out:
# ['step',
#  'type',
#  'amount',
#  'nameOrig',
#  'oldbalanceOrg',
#  'newbalanceOrig',
#  'nameDest',
#  'oldbalanceDest',
#  'newbalanceDest',
#  'isFraud',
#  'isFlaggedFraud']

# %%
df_sample.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df_sample["isFraud"].value_counts()
# Out:
# isFraud
# 0    9932
# 1      68
# Name: count, dtype: int64

# %%
df_sample["isFraud"].value_counts(normalize=True) * 100
# Out:
# isFraud
# 0    99.32
# 1     0.68
# Name: proportion, dtype: float64

# %%
print("Rows and columns:", df_sample.shape)
# Out:
# Rows and columns: (10000, 11)

# %%
df_sample.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df_sample.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df_sample.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   step            10000 non-null  int64
#  1   type            10000 non-null  str
#  2   amount          10000 non-null  float64
#  3   nameOrig        10000 non-null  str
#  4   oldbalanceOrg   10000 non-null  float64
#  5   newbalanceOrig  10000 non-null  float64
#  6   nameDest        10000 non-null  str
#  7   oldbalanceDest  10000 non-null  float64
#  8   newbalanceDest  10000 non-null  float64
#  9   isFraud         10000 non-null  int64
#  10  isFlaggedFraud  10000 non-null  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 1.1 MB

# %%
df_sample["isFraud"].value_counts()
# Out:
# isFraud
# 0    9932
# 1      68
# Name: count, dtype: int64

# %%
df_sample.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   step            10000 non-null  int64
#  1   type            10000 non-null  str
#  2   amount          10000 non-null  float64
#  3   nameOrig        10000 non-null  str
#  4   oldbalanceOrg   10000 non-null  float64
#  5   newbalanceOrig  10000 non-null  float64
#  6   nameDest        10000 non-null  str
#  7   oldbalanceDest  10000 non-null  float64
#  8   newbalanceDest  10000 non-null  float64
#  9   isFraud         10000 non-null  int64
#  10  isFlaggedFraud  10000 non-null  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 1.1 MB

# %%
df_sample.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df_sample.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_sample["type"].value_counts()
# Out:
# type
# PAYMENT     5465
# CASH_IN     1949
# CASH_OUT    1321
# TRANSFER     921
# DEBIT        344
# Name: count, dtype: int64

# %%
df_sample["type"].value_counts().plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_sample["type"].value_counts().plot(kind="bar")
#
# File c:\fraud detection system\.venv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File c:\fraud detection system\.venv\Lib\site-packages\pandas\plotting\_core.py:2253, in _get_plot_backend(backend)
#    2250 if backend_str in _backends:
#    2251     return _backends[backend_str]
# -> 2253 module = _load_backend(backend_str)
#    2254 _backends[backend_str] = module
# ...

# %%
import matplotlib.pyplot as plt

print("Matplotlib is working!")
# Out:
# Matplotlib is working!

# %%
df_sample["type"].value_counts().plot(kind="bar")
plt.show()

# %%
import matplotlib.pyplot as plt

df_sample["type"].value_counts().plot(kind="bar")
plt.show()

# %%
df_sample["amount"].describe()
# Out:
# count    1.000000e+04
# mean     1.035467e+05
# std      2.663072e+05
# min      2.390000e+00
# 25%      4.397530e+03
# 50%      1.285874e+04
# 75%      1.143825e+05
# max      1.000000e+07
# Name: amount, dtype: float64

# %%
df_sample.groupby("isFraud")["amount"].describe()
# Out:
#           count           mean           std     min        25%        50%  \
# isFraud
# 0        9932.0  100603.239233  2.222295e+05    2.39   4372.755  12740.655
# 1          68.0  533463.638676  1.753539e+06  181.00  14949.840  28644.760
#
#                  75%          max
# isFraud
# 0        114059.9425   3776389.09
# 1        181561.7975  10000000.00

# %%
pd.crosstab(
    df_sample["type"],
    df_sample["isFraud"]
)
# Out:
# isFraud      0   1
# type
# CASH_IN   1949   0
# CASH_OUT  1286  35
# DEBIT      344   0
# PAYMENT   5465   0
# TRANSFER   888  33

# %%
fraud_by_type = pd.crosstab(
    df_sample["type"],
    df_sample["isFraud"],
    normalize="index"
) * 100

fraud_by_type
# Out:
# isFraud            0         1
# type
# CASH_IN   100.000000  0.000000
# CASH_OUT   97.350492  2.649508
# DEBIT     100.000000  0.000000
# PAYMENT   100.000000  0.000000
# TRANSFER   96.416938  3.583062

# %%
fraud_sample = df_sample[df_sample["isFraud"] == 1]

fraud_sample.head()
# Out:
#      step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2       1  TRANSFER    181.0  C1305486145          181.0             0.0
# 3       1  CASH_OUT    181.0   C840083671          181.0             0.0
# 251     1  TRANSFER   2806.0  C1420196421         2806.0             0.0
# 252     1  CASH_OUT   2806.0  C2101527076         2806.0             0.0
# 680     1  TRANSFER  20128.0   C137533655        20128.0             0.0
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 2     C553264065             0.0             0.0        1               0
# 3      C38997010         21182.0             0.0        1               0
# 251   C972765878             0.0             0.0        1               0
# 252  C1007251739         26202.0             0.0        1               0
# 680  C1848415041             0.0             0.0        1               0

# %%
fraud_sample = df_sample[df_sample["isFraud"] == 1]

fraud_sample.head()
# Out:
#      step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2       1  TRANSFER    181.0  C1305486145          181.0             0.0
# 3       1  CASH_OUT    181.0   C840083671          181.0             0.0
# 251     1  TRANSFER   2806.0  C1420196421         2806.0             0.0
# 252     1  CASH_OUT   2806.0  C2101527076         2806.0             0.0
# 680     1  TRANSFER  20128.0   C137533655        20128.0             0.0
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 2     C553264065             0.0             0.0        1               0
# 3      C38997010         21182.0             0.0        1               0
# 251   C972765878             0.0             0.0        1               0
# 252  C1007251739         26202.0             0.0        1               0
# 680  C1848415041             0.0             0.0        1               0

# %%
fraud_sample = df_sample[df_sample["isFraud"] == 1]

# %%
fraud_sample.head()
# Out:
#      step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2       1  TRANSFER    181.0  C1305486145          181.0             0.0
# 3       1  CASH_OUT    181.0   C840083671          181.0             0.0
# 251     1  TRANSFER   2806.0  C1420196421         2806.0             0.0
# 252     1  CASH_OUT   2806.0  C2101527076         2806.0             0.0
# 680     1  TRANSFER  20128.0   C137533655        20128.0             0.0
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 2     C553264065             0.0             0.0        1               0
# 3      C38997010         21182.0             0.0        1               0
# 251   C972765878             0.0             0.0        1               0
# 252  C1007251739         26202.0             0.0        1               0
# 680  C1848415041             0.0             0.0        1               0

# %%
fraud_sample[[
    "step",
    "type",
    "amount",
    "nameOrig",
    "oldbalanceOrg",
    "newbalanceOrig",
    "nameDest",
    "oldbalanceDest",
    "newbalanceDest"
]].head(10)
# Out:
#       step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        1  TRANSFER      181.00  C1305486145         181.00             0.0
# 3        1  CASH_OUT      181.00   C840083671         181.00             0.0
# 251      1  TRANSFER     2806.00  C1420196421        2806.00             0.0
# 252      1  CASH_OUT     2806.00  C2101527076        2806.00             0.0
# 680      1  TRANSFER    20128.00   C137533655       20128.00             0.0
# 681      1  CASH_OUT    20128.00  C1118430673       20128.00             0.0
# 724      1  CASH_OUT   416001.33   C749981943           0.00             0.0
# 969      1  TRANSFER  1277212.77  C1334405552     1277212.77             0.0
# 970      1  CASH_OUT  1277212.77   C467632528     1277212.77             0.0
# 1115     1  TRANSFER    35063.63  C1364127192       35063.63             0.0
#
#          nameDest  oldbalanceDest  newbalanceDest
# 2      C553264065             0.0            0.00
# ...

# %%
fraud_sample[[
    "step",
    "type",
    "amount",
    "nameOrig",
    "oldbalanceOrg",
    "newbalanceOrig",
    "nameDest",
    "oldbalanceDest",
    "newbalanceDest"
]].head(10)
# Out:
#       step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        1  TRANSFER      181.00  C1305486145         181.00             0.0
# 3        1  CASH_OUT      181.00   C840083671         181.00             0.0
# 251      1  TRANSFER     2806.00  C1420196421        2806.00             0.0
# 252      1  CASH_OUT     2806.00  C2101527076        2806.00             0.0
# 680      1  TRANSFER    20128.00   C137533655       20128.00             0.0
# 681      1  CASH_OUT    20128.00  C1118430673       20128.00             0.0
# 724      1  CASH_OUT   416001.33   C749981943           0.00             0.0
# 969      1  TRANSFER  1277212.77  C1334405552     1277212.77             0.0
# 970      1  CASH_OUT  1277212.77   C467632528     1277212.77             0.0
# 1115     1  TRANSFER    35063.63  C1364127192       35063.63             0.0
#
#          nameDest  oldbalanceDest  newbalanceDest
# 2      C553264065             0.0            0.00
# ...

# %%
balance_depletion = oldbalanceOrg - newbalanceOrig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 balance_depletion = oldbalanceOrg - newbalanceOrig
#
# NameError: name 'oldbalanceOrg' is not defined

# %%
df_sample["balance_depletion"] = (
    df_sample["oldbalanceOrg"] - df_sample["newbalanceOrig"]
)

# %%
df_sample[
    ["oldbalanceOrg", "amount", "newbalanceOrig", "balance_depletion"]
].head()
# Out:
#    oldbalanceOrg    amount  newbalanceOrig  balance_depletion
# 0       170136.0   9839.64       160296.36            9839.64
# 1        21249.0   1864.28        19384.72            1864.28
# 2          181.0    181.00            0.00             181.00
# 3          181.0    181.00            0.00             181.00
# 4        41554.0  11668.14        29885.86           11668.14

# %%
df_sample["amount_to_balance_ratio"] = (
    df_sample["amount"] / (df_sample["oldbalanceOrg"] + 1)
)

# %%
df_sample[
    ["amount", "oldbalanceOrg", "amount_to_balance_ratio"]
].head()
# Out:
#      amount  oldbalanceOrg  amount_to_balance_ratio
# 0   9839.64       170136.0                 0.057834
# 1   1864.28        21249.0                 0.087731
# 2    181.00          181.0                 0.994505
# 3    181.00          181.0                 0.994505
# 4  11668.14        41554.0                 0.280788

# %%
df_sample.drop(
    columns=["balance_depletion", "amount_to_balance_ratio"],
    inplace=True
)

# %%
df_sample["amount_range"] = pd.cut(
    df_sample["amount"],
    bins=[0, 1000, 10000, 100000, 1000000, float("inf")],
    labels=[
        "0-1K",
        "1K-10K",
        "10K-100K",
        "100K-1M",
        "Above 1M"
    ]
)

# %%
pd.crosstab(
    df_sample["amount_range"],
    df_sample["isFraud"]
)
# Out:
# isFraud          0   1
# amount_range
# 0-1K           604   2
# 1K-10K        3854   2
# 10K-100K      2799  42
# 100K-1M       2560  14
# Above 1M       115   8

# %%
df_sample.drop(columns=["amount_range"], inplace=True)

# %%
df_sample.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
transaction_counts = df_sample["nameOrig"].value_counts()

transaction_counts.head(10)
# Out:
# nameOrig
# C1231006815    1
# C1666544295    1
# C1305486145    1
# C840083671     1
# C2048537720    1
# C90045638      1
# C154988899     1
# C1912850431    1
# C1265012928    1
# C712410124     1
# Name: count, dtype: int64

# %%
transaction_counts.describe()
# Out:
# count    10000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: count, dtype: float64

# %%
df_sample["user_transaction_count"] = (
    df_sample.groupby("nameOrig")["nameOrig"]
    .transform("count")
)

# %%
df_sample[
    ["nameOrig", "amount", "user_transaction_count", "isFraud"]
].head(10)
# Out:
#       nameOrig    amount  user_transaction_count  isFraud
# 0  C1231006815   9839.64                       1        0
# 1  C1666544295   1864.28                       1        0
# 2  C1305486145    181.00                       1        1
# 3   C840083671    181.00                       1        1
# 4  C2048537720  11668.14                       1        0
# 5    C90045638   7817.71                       1        0
# 6   C154988899   7107.77                       1        0
# 7  C1912850431   7861.64                       1        0
# 8  C1265012928   4024.36                       1        0
# 9   C712410124   5337.77                       1        0

# %%
transaction_counts.describe()
# Out:
# count    10000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: count, dtype: float64

# %%
import os

file_path = "../data/raw/PS_20174392719_1491204439457_log.csv"

file_size_gb = os.path.getsize(file_path) / (1024 ** 3)

print(f"File size: {file_size_gb:.2f} GB")
# Out:
# File size: 0.46 GB

# %%
with open(file_path, "rb") as f:
    row_count = sum(1 for _ in f) - 1

print("Total rows:", row_count)
# Out:
# Total rows: 6362620

# %%
df_sample["user_transaction_count"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: user_transaction_count, Length: 10000, dtype: int64

# %%
df_sample.drop(
    columns=["user_transaction_count"],
    inplace=True,
    errors="ignore"
)

# %%
file_size_gb = os.path.getsize(file_path) / (1024 ** 3)

print(f"File size: {file_size_gb:.2f} GB")
# Out:
# File size: 0.46 GB

# %%
with open(file_path, "rb") as f:
    row_count = sum(1 for _ in f) - 1

print("Total rows:", row_count)
# Out:
# Total rows: 6362620

# %%
import psutil

ram_gb = psutil.virtual_memory().total / (1024 ** 3)

print(f"Total RAM: {ram_gb:.2f} GB")
# Out:
# Total RAM: 23.69 GB

# %%
import psutil

ram_gb = psutil.virtual_memory().total / (1024 ** 3)

print(f"Total RAM: {ram_gb:.2f} GB")
# Out:
# Total RAM: 23.69 GB

# %%
import pandas as pd
import numpy as np
import os

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Pandas: 3.0.5
# NumPy: 2.5.2

# %%
RAW_FILE = "../data/raw/PS_20174392719_1491204439457_log.csv"

PROCESSED_DIR = "../data/processed"

os.makedirs(PROCESSED_DIR, exist_ok=True)

print("Raw file:", RAW_FILE)
print("Processed directory:", PROCESSED_DIR)
# Out:
# Raw file: ../data/raw/PS_20174392719_1491204439457_log.csv
# Processed directory: ../data/processed

# %%
chunksize = 100_000

chunk_count = 0
total_rows = 0

for chunk in pd.read_csv(RAW_FILE, chunksize=chunksize):
    chunk_count += 1
    total_rows += len(chunk)

    if chunk_count <= 3:
        print(
            f"Chunk {chunk_count}: "
            f"{len(chunk):,} rows"
        )

print(f"\nTotal chunks: {chunk_count}")
print(f"Total rows: {total_rows:,}")
# Out:
# Chunk 1: 100,000 rows
# Chunk 2: 100,000 rows
# Chunk 3: 100,000 rows
#
# Total chunks: 64
# Total rows: 6,362,620

# %%
pd.read_csv(RAW_FILE, chunksize=100_000)
